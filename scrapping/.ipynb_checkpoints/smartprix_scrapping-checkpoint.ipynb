# %%
with open("../scrapping/smartprix.html",'r',encoding='utf-8') as f:
    html = f.read()

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'lxml')

# %%
container = soup.find_all('div',class_='sm-product has-tag has-features has-actions')

# %%
names = []
prices = []
spec_score = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
os = []
other_specs = []
for contain in container:
    try:
        names.append(contain.find('h2').text)
    except:
        names.append(np.nan)

    try:
        prices.append(contain.find('span',class_='price').text)
    except:
        prices.append(np.nan)
        
    try:
        spec_score.append(contain.find('div',class_='score rank-2-bg').find('b').text)
    except:
        spec_score.append(np.nan)

    x = contain.find('ul',class_='sm-feat specs').find_all('li')
    
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        os.append(x[6].text)
    except:
        os.append(np.nan)
    try:
        other_specs.append(x[7].text)
    except:
        other_specs.append(np.nan)

# %%
len(display)
# Out:
# 1020

# %%
df = pd.DataFrame({
        'model':names,
        'prices':prices,
        'rating':spec_score,
        'sim':sim,
        'processor':processor,
        'ram':ram,
        'battery':battery,
        'display':display,
        'camera':camera,
        'os':os,
        'other_specs':other_specs
        })

# %%
df
# Out:
#                              model     prices rating  \
# 0          Motorola Edge 70 Fusion    ₹27,589     70
# 1              Apple iPhone 18 Pro  ₹1,64,900    NaN
# 2                     Realme P3 5G    ₹15,999     61
# 3     Xiaomi Redmi Note 17 Pro Max    ₹49,999    NaN
# 4                  Apple iPhone 17    ₹82,900     76
# ...                            ...        ...    ...
# 1015   Realme C15 (4GB RAM + 64GB)    ₹12,999    NaN
# 1016                 Micromax X380     ₹1,154    NaN
# 1017                       Lava A1     ₹1,045    NaN
# 1018                Xiaomi Redmi 5    ₹11,999    NaN
# 1019                 Micromax X415       ₹998    NaN
#
#                                                     sim  \
# 0                 Dual Sim, 5G, VoLTE, Vo5G, NFC, Wi-Fi
# 1                 Dual Sim, 5G, VoLTE, NFC, eSIM, Wi-Fi
# 2                       Dual Sim, 5G, VoLTE, NFC, Wi-Fi
# 3     Dual Sim, 5G, VoLTE, NFC, eSIM, Wi-Fi, IR Blaster
# 4                 Dual Sim, 5G, VoLTE, NFC, eSIM, Wi-Fi
# ...                                                 ...
# 1015                         Dual Sim, 4G, VoLTE, Wi-Fi
# 1016                                           Dual Sim
# 1017                                           Dual Sim
# 1018             Dual Sim, 4G, VoLTE, Wi-Fi, IR Blaster
# 1019                                           Dual Sim
#
#                                              processor  \
# 0     Snapdragon 7s Gen4, Octa Core, 2.7 GHz Processor
# 1                   Apple A20 Pro, Hexa Core Processor
# 2      Snapdragon 6 Gen4, Octa Core, 2.3 GHz Processor
# 3      Snapdragon 6 Gen5, Octa Core, 2.6 GHz Processor
# 4                       Apple A19, Hexa Core Processor
# ...                                                ...
# 1015          Helio  G35, Octa Core, 2.3 GHz Processor
# 1016                          32 MB RAM, 32 MB inbuilt
# 1017                                   1 MHz Processor
# 1018      Snapdragon 450, Octa Core, 1.8 GHz Processor
# 1019                          32 MB RAM, 32 MB inbuilt
#
#                             ram                                    battery  \
# 0      8 GB RAM, 128 GB inbuilt    7000 mAh Battery with 68W Fast Charging
# 1     12 GB RAM, 256 GB inbuilt        4056 mAh Battery with Fast Charging
# 2      6 GB RAM, 128 GB inbuilt    6000 mAh Battery with 45W Fast Charging
# 3      8 GB RAM, 256 GB inbuilt  10000 mAh Battery with 100W Fast Charging
# 4      8 GB RAM, 256 GB inbuilt        3692 mAh Battery with Fast Charging
# ...                         ...                                        ...
# 1015    4 GB RAM, 64 GB inbuilt    6000 mAh Battery with 18W Fast Charging
# 1016           2500 mAh Battery          1.77 inches, 240 x 320 px Display
# 1017   24 MB RAM, 24 MB inbuilt                            800 mAh Battery
# 1018    4 GB RAM, 64 GB inbuilt                           3300 mAh Battery
# 1019           1000 mAh Battery           1.7 inches, 128 x 160 px Display
#
#                                                 display  \
# 0     6.8 inches, 1272 x 2772 px, 144 Hz Display wit...
# 1     6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# 2     6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 3     6.83 inches, 1280 x 2772 px, 120 Hz Display wi...
# 4     6.3 inches, 1206 x 2622 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.52 inches, 720 x 1600 px Display with Water ...
# 1016                                 0.3 MP Rear Camera
# 1017                  1.77 inches, 240 x 320 px Display
# 1018                  5.7 inches, 720 x 1440 px Display
# 1019                                0.08 MP Rear Camera
#
#                                                  camera  \
# 0     50 MP + 13 MP + Dedicated 3-in-1 light sensor ...
# 1     48 MP + 48 MP + 48 MP Triple Rear & 18 MP Fron...
# 2           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 3           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 4          48 MP + 48 MP Dual Rear & 18 MP Front Camera
# ...                                                 ...
# 1015                13 MP Quad Rear & 8 MP Front Camera
# 1016                                        No FM Radio
# 1017                                 0.3 MP Rear Camera
# 1018                     12 MP Rear & 5 MP Front Camera
# 1019                   Memory Card Supported, upto 8 GB
#
#                                       os              other_specs
# 0                            Android v16              No FM Radio
# 1              Memory Card Not Supported                  iOS v27
# 2                            Android v15              No FM Radio
# 3                            Android v16              No FM Radio
# 4              Memory Card Not Supported                  iOS v26
# ...                                  ...                      ...
# 1015  Memory Card Supported, upto 256 GB              Android v10
# 1016                                 NaN                      NaN
# 1017   Memory Card Supported, upto 32 GB                      NaN
# 1018   Memory Card (Hybrid), upto 128 GB  Android v7.1.2 (Nougat)
# 1019                           Bluetooth                      NaN
#
# [1020 rows x 11 columns]

# %%
df.to_csv("../dataset/Smartphone_uncleaned.csv",index=False)
